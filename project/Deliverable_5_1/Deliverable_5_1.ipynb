# %%
# %load_ext autoreload
# %autoreload 2

# Get parent directory and add to sys.path
import os; import sys
import numpy as np
parent_dir = os.path.dirname(os.getcwd())
sys.path.append(parent_dir)

# Require ipympl
# %matplotlib widget

# %%
# MPC import
from Deliverable_5_1.LinearMPC.MPCVelControl import MPCVelControl
from PIControl.PIControl import PIControl

from src.rocket import Rocket
from src.vel_rocket_vis import RocketVis, plot_static_states_inputs

rocket_obj_path = os.path.join(parent_dir, "Cartoon_rocket.obj")
rocket_params_path = os.path.join(parent_dir, "rocket.yaml")

# %%
Ts = 0.05
sim_time = 10; H = 5.0
x0 = np.array([0, 0, 0, 0, 0, 0, 5, 5, 10, 0, 0, 1])  # initial state
x_target = np.zeros((12,))

rocket = Rocket(Ts=Ts, model_params_filepath=rocket_params_path)
mpc = MPCVelControl().new_controller(rocket, Ts, H)

# Static mass change and zero fuel rate
rocket.mass = 1.5
rocket.fuel_rate = 0.0
t_cl, x_cl, u_cl, t_ol, x_ol, u_ol, ref = rocket.simulate_control(mpc, sim_time, H, x0, x_target=x_target, method='nonlinear')

vis = RocketVis(rocket, rocket_obj_path)
vis.anim_rate = 1.0
vis.animate(t_cl[:-1], x_cl[:,:-1], u_cl, Ref=ref[:,:-1], T_ol=t_ol[...,:-1], X_ol=x_ol, U_ol=u_ol);
# Out:
# D:\Work\Courses\MPC-Course-EPFL\project\Deliverable_5_1\LinearMPC\MPCControl_xvel.py:34: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   # x in X = { x | Fx <= f }
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Simulating time 0.00:
# ---------------------------------------------------------------------------
# SolverError                               Traceback (most recent call last)
# Cell In[15], line 12
#      10 rocket.mass = 1.5
#      11 rocket.fuel_rate = 0.0
# ---> 12 t_cl, x_cl, u_cl, t_ol, x_ol, u_ol, ref = rocket.simulate_control(mpc, sim_time, H, x0, x_target=x_target, method='nonlinear')
#      14 vis = RocketVis(rocket, rocket_obj_path)
#      15 vis.anim_rate = 1.0
#
# File D:\Work\Courses\MPC-Course-EPFL\project\src\rocket.py:430, in Rocket.simulate_control(self, mpc, sim_time, H, x0, method, x_target, u_target, pos_control)
#     428 if pos_control is not None:
#     429     x_target[6:9, k] = pos_control.get_u(x_cl[9:12, k])
# --> 430 u_cl[:, k], x_ol[..., k], u_ol[..., k], t_ol[..., k] = mpc.get_u(t_cl[k], x_cl[:, k], x_target=x_target[:, k], u_target=u_target)
#     431 x_cl[:, k+1] = current_rocket.simulate_step(x_cl[:, k], self.Ts, u_cl[:, k], method=method)
#     432 mpc.estimate_parameters(x_cl[:, k:k+2], u_cl[:, k:k+1])
#
# File D:\Work\Courses\MPC-Course-EPFL\project\Deliverable_5_1\LinearMPC\MPCVelControl.py:67, in MPCVelControl.get_u(self, t0, x0, x_target, u_target)
#      63 if u_target is None:
#      64     u_target = self.us
#      66 u0[self.mpc_x.u_ids], x_traj[self.mpc_x.x_ids], u_traj[self.mpc_x.u_ids] = (
# ---> 67     self.mpc_x.get_u(
#      68         x0[self.mpc_x.x_ids],
#      69         x_target[self.mpc_x.x_ids],
#      70         u_target[self.mpc_x.u_ids],
#      71     )
#      72 )
#      73 u0[self.mpc_y.u_ids], x_traj[self.mpc_y.x_ids], u_traj[self.mpc_y.u_ids] = (
#      74     self.mpc_y.get_u(
#      75         x0[self.mpc_y.x_ids],
#    (...)     78     )
#      79 )
#      80 u0[self.mpc_z.u_ids], x_traj[self.mpc_z.x_ids], u_traj[self.mpc_z.u_ids] = (
#      81     self.mpc_z.get_u(
#      82         x0[self.mpc_z.x_ids],
#    (...)     85     )
#      86 )
#
# File D:\Work\Courses\MPC-Course-EPFL\project\Deliverable_5_1\LinearMPC\MPCControl_xvel.py:108, in MPCControl_xvel.get_u(self, x0, x_target, u_target)
#     103 def get_u(
#     104     self, x0: np.ndarray, x_target: np.ndarray = None, u_target: np.ndarray = None
#     105 ) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
#     106     #################################################
#     107     # YOUR CODE HERE
# --> 108     u0, x_traj, u_traj = super().get_u(x0, x_target, u_target)
#     109     # YOUR CODE HERE
#     110     #################################################
#     112     return u0, x_traj, u_traj
#
# File D:\Work\Courses\MPC-Course-EPFL\project\Deliverable_5_1\LinearMPC\MPCControl_base.py:9, in get_u(self, x0, x_target, u_target)
#       8 class MPCControl_base:
# ----> 9     """Complete states indices"""
#      11     x_ids: np.ndarray
#      12     u_ids: np.ndarray
#
# File ~\AppData\Local\anaconda3\envs\mpc2025\Lib\site-packages\cvxpy\problems\problem.py:609, in Problem.solve(self, *args, **kwargs)
#     606         raise ValueError(
#     607             "Cannot specify both 'solver' and 'solver_path'. Please choose one.")
#     608     return self._solve_solver_path(solve_func,solver_path, args, kwargs)
# --> 609 return solve_func(self, *args, **kwargs)
#
# File ~\AppData\Local\anaconda3\envs\mpc2025\Lib\site-packages\cvxpy\problems\problem.py:1222, in Problem._solve(self, solver, warm_start, verbose, bibtex, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1220 end = time.time()
#    1221 self._solve_time = end - start
# -> 1222 self.unpack_results(solution, solving_chain, inverse_data)
#    1223 if verbose:
#    1224     print(_FOOTER)
#
# File ~\AppData\Local\anaconda3\envs\mpc2025\Lib\site-packages\cvxpy\problems\problem.py:1547, in Problem.unpack_results(self, solution, chain, inverse_data)
#    1545     warnings.warn(INF_OR_UNB_MESSAGE)
#    1546 if solution.status in s.ERROR:
# -> 1547     raise error.SolverError(
#    1548             "Solver '%s' failed. " % chain.solver.name() +
#    1549             "Try another solver, or solve with verbose=True for more "
#    1550             "information.")
#    1552 self.unpack(solution)
#    1553 self._solver_stats = SolverStats.from_dict(self._solution.attr,
#    1554                                  chain.solver.name())
#
# SolverError: Solver 'GUROBI' failed. Try another solver, or solve with verbose=True for more information.
